# %% [markdown]
# # Great Lakes Fishing Data and Analysis

# %% [markdown]
# *By Nathaniel F. Lacelle*

# %% [markdown]
# The fishing dataset used in this notebook was collected from over 10 years of fishing on the south shore of Lake Superior- the largest fresh water lake on the planet. The dataset has an entry for every fish caught, almost 2,000 over the last 10 years, and includes simple weather metrics around when the fish was caught along with some information on the fish caught. The logs contain some useful information and context for each fish, however they (and other columns) contain sensitive information. For that reason the raw data is not shared and the cleaned data is available instead.

# %% [markdown]
# The goal of these notebooks is to clean the data into a presentable form, use online weather APIs to collect more information, perform simple data analysis and exploration, and fit some models for predicting good fishing days

# %% [markdown]
# The fisherman who collected this data is my father, and he was kind enough to let me share the cleaned version with anyone who might want to explore it.

# %% [markdown]
# ***Some sections are unfinished***
#
# *Specifically, the [Fetching Historical Weather](02-Fetching-Historical-Weather.ipynb) and the [Summary](05-Summary.ipynb)*.
#
# *The other sections are mostly finished. I plan on finishing the two unfinished sections soon.*

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# ### [1. Cleaning](01-Cleaning.ipynb)

# %% [markdown]
# ### [2. Fetching Historical Weather](02-Fetching-Historical-Weather.ipynb)

# %% [markdown]
# ### [3. Data Analysis](03-Data-Analysis.ipynb)

# %% [markdown]
# ### [4. Model Fitting](04-Model-Fitting.ipynb)

# %% [markdown]
# ### [5. Summary](05-Summary.ipynb)
